# %%
### Для проверки данного задания вам потребуется программное обеспечение Anaconda, подходящее под вашу версию операционной системы
### И Jupyter Notebook. который входит в пакет Anaconda


###1) Соединение БД с Python
###Если вдруг кого не было на семинарах и еще не грузил эту штуку, для MAC OS пишется по другому см коммент ниже
pip install psycopg2
###pip install psycopg2-binary
# Out:
#   File "<ipython-input-2-3db8d7e0a752>", line 3
#     pip install psycopg2
#               ^
# SyntaxError: invalid syntax

# %%
####импортируем всякие нужные штучки
import psycopg2 # драйвер для postgresql
import getpass  # прячем параль, чтобы не писать его в параметрах
### создаем соединение
conn=psycopg2.connect(user='postgres',
                      database='postgres',##название базы данных мб другое, как и другие параметры соединения, измените под свои
                      host='localhost',
                      port='5432',
                      password=getpass.getpass('Insert password: ')
                        )
print(conn.get_dsn_parameters())
# Out:
# Insert password: ········
# {'user': 'postgres', 'dbname': 'postgres', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}

# %%
# 2 пункт, чтобы вывести нужные данные из БД
import pandas as pd
query="SELECT * FROM bond_description_task  WHERE \"Status\"='В обращении' AND \"CouponType\"='Постоянный' OR \"CouponType\"='Дисконт' OR \"RateTypeNameRus_NRD\"='Нулевой';"
data=pd.read_sql_query(query,conn)
data.head(10)
# Out:
#   ISIN, RegCode, NRDCode FinToolType SecurityType            SecurityKind  \
# 0           XS1092320099   Облигация     ЕвроКорп            Классические
# 1           XS1076087375   Облигация     ЕвроКорп  Ноты участия в кредите
# 2           XS0974469206   Облигация     ЕвроКорп  Ноты участия в кредите
# 3           XS0868348987   Облигация     ЕвроКорп            Классические
# 4           RU000A0JRHE6   Облигация         Корп            Классические
# 5           XS0918604496   Облигация     ЕвроКорп            Классические
# 6           XS0995845566   Облигация     ЕвроКорп  Ноты участия в кредите
# 7           RU000A0JSLP2   Облигация         Корп            Классические
# 8           RU000A0JSLQ0   Облигация         Корп            Классические
# 9           RU000A0JSLR8   Облигация         Корп            Классические
#
#    CouponType      RateTypeNameRus_NRD CouponTypeName_NRD  HaveOffer  \
# 0  Постоянный  с фиксированной ставкой        Полугодовой       True
# 1  Постоянный  с фиксированной ставкой          Ежегодный      False
# 2  Постоянный  с фиксированной ставкой        Полугодовой      False
# 3  Постоянный  с фиксированной ставкой        Полугодовой      False
# 4  Постоянный  с фиксированной ставкой          Ежегодный      False
# 5  Постоянный  с фиксированной ставкой        Полугодовой      False
# 6  Постоянный  с фиксированной ставкой        Полугодовой      False
# 7  Постоянный  с фиксированной ставкой          Ежегодный      False
# 8  Постоянный  с фиксированной ставкой          Ежегодный      False
# 9  Постоянный  с фиксированной ставкой          Ежегодный      False
#
#    AmortisedMty  MaturityGroup  ...  CurrentFaceValue_NRD  \
# 0         False  Среднесрочные  ...          1.000000e+03
# 1         False  Краткосрочные  ...          1.000000e+03
# 2         False  Среднесрочные  ...          1.000000e+03
# 3         False  Краткосрочные  ...          1.000000e+05
# 4         False  Среднесрочные  ...          1.000000e+09
# 5         False  Среднесрочные  ...          1.000000e+03
# 6         False  Среднесрочные  ...          1.000000e+03
# 7         False  Среднесрочные  ...          1.000000e+07
# 8         False  Среднесрочные  ...          1.000000e+07
# 9         False  Среднесрочные  ...          1.000000e+07
#
#            BorrowerName BorrowerOKPO  BorrowerSector BorrowerUID  \
# 0           4finance AS          NaN            None       95365
# 1         ABH Financial          NaN            None       87458
# 2  Borets International          NaN            None       94896
# 3       Caterpillar FCS          NaN            None        7838
# 4             EBRD Bank          NaN            None        6582
# 5      Eurasia Drilling          NaN            None       93311
# 6  Hacienda Investments          NaN            None       94944
# 7                   IFC          NaN            None        6925
# 8                   IFC          NaN            None        6925
# 9                   IFC          NaN            None        6925
#
#                   IssuerName                             IssuerName_NRD  \
# 0               4finance S.A                              4finance S.A.
# 1      Alfa Holding Issuance                  Alfa Holding Issuance plc
# 2             Borets Finance                     Borets Finance Limited
# 3  Caterpillar InternFinance  Caterpillar International Finance Limited
# 4                  EBRD Bank  Европейский Банк Реконструкции и Развития
# 5                EDC Finance                        EDC Finance Limited
# 6                DME Airport                        DME Airport Limited
# 7                        IFC                                        МФК
# 8                        IFC                                        МФК
# 9                        IFC                                        МФК
#
#   IssuerOKPO NumGuarantors  EndMtyDate
# 0        NaN             9  2019-08-14
# 1        NaN             0  2017-06-10
# 2        NaN             5  2018-09-26
# 3        NaN             1  2015-12-20
# 4        NaN             0  2016-06-15
# 5        NaN             3  2020-04-17
# 6        NaN             8  2018-11-26
# 7        NaN             0  2017-11-26
# 8        NaN             0  2017-11-26
# 9        NaN             0  2017-11-26
#
# [10 rows x 51 columns]

# %%
###3 задание
def my_fun(ISIN, time, db_login)
    mport pandas as pd
    conn=psycopg2.connect(user=db_login['user'],
                      database=db_login['database'],
                      host=db_login['host'],
                      port=db_login['port'],
                      password=getpass.getpass('Insert password: '))
    query="SELECT * FROM bond_description_task WHERE \"Status\"='В обращении' AND \"CouponType\"='Постоянный' OR \"CouponType\"='Дисконт' OR \"RateTypeNameRus_NRD\"='Нулевой';"
    orders=pd.read_sql_query(query,conn)
    
  oblig=
    

return results
# Out:
#   File "<ipython-input-13-df242e0fc032>", line 2
#     def my_fun(ISIN, time, db_login)
#                                     ^
# SyntaxError: invalid syntax

# %%
###Бонусное задание ( даже если 3 пункт неправильный, это не значит, что не могу запрос внутрь функции поставить))))
login={'user':'postgres', 'database':'postgres', 'host':'localhost', 'port':'5432'}
x=my_fun('\'ISIN\', time ,conn)
x['oblig']
##пусть матрица из 3 пункта называется oblig
